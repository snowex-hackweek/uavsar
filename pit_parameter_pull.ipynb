# %% [markdown]
# ### Import necessary packages

# %%
# Standard imports (these will help with accessing files)
import os
from glob import glob

# Core statistical/dataframe packages
import numpy as np
import pandas as pd

# For plotting
import matplotlib.pyplot as plt
import seaborn as sns #pretty plot styles/customization

# unique imports
import s3fs #access data from the AWS s3 bucket

# %% [markdown]
# #### From Megan's tutorial: getting data from the amazon cloud server

# %%
# Uses AWS credentials on machine
fs = s3fs.S3FileSystem() 
# which data bucket?
bucket = 'snowex-data'

# flist = fs.ls(f'{bucket}') #shows everything in the bucket, can sort through for specific data
flist = fs.ls(f'{bucket}/tutorial-data/core-datasets/pits/') #fetches all GMIOP snowpit data
# show list of files
# print('File list is: ', flist)

# list comprehension to pull only .csv files (not .xlsx or .jpgs)
# suffix='.csv' #we can fuss with this to more specifically pull a single parameter like _stratigraphy_v01.csv
# csv_files = [filename for filename in flist if filename.endswith(suffix)]
# csv_files

# get just strat csvs
suffix = 'stratigraphy_v01.csv'
strat_files = [filename for filename in flist if filename.endswith(suffix)]
strat_files

# TODO: write a loop for all pit params?
# also TODO: where snotel data?
# Out:
# ['snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200128_1N6_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200128_2N4_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200128_3N22_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200128_3N53_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200128_4N2_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200128_5N10_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200128_5N19_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200128_6N18_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200128_7N57_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200128_8N25_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200128_8N55_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200128_8N58_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200128_9N59_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200129_1S1_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200129_2S25_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200129_2S36_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200129_2S3_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200129_2S48_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200129_3S47_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200129_3S5_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200129_5S24_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200129_5S43_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200129_6C37_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200129_6S19_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200129_8S30_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200129_9S51_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200130_2C33_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200130_2S35_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200130_4N27_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200130_5C20_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200130_5C21_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200130_5N41_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200130_5S31_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200130_6N31_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200130_6N36_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200130_7C15_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200130_8C25_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200130_8N34_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200130_8N38_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200130_9C17_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200130_9C19_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200130_9N29_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200131_1C14_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200131_1C1_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200131_1C7_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200131_1C8_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200131_2C2_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200131_2C3_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200131_2C4_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200131_2C6_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200131_2C9_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200131_2N12_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200131_4C30_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200131_6C10_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200131_6C24_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200131_8C22_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200131_8C26_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200131_8S28_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200131_9C28_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200201_1S8_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200201_2N48_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200201_2S11_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200201_2S37_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200201_3S14_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200201_3S38_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200201_5N50_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200201_5S21_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200201_6C34_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200201_6N46_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200201_8N45_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200201_9N44_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200201_9S39_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200201_9S40_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200203_GML_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200204_2S27_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200204_2S46_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200204_3S33_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200204_3S52_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200204_5S29_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200204_5S42_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200204_5S49_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200204_6S34_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200204_6S44_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200204_7N40_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200204_8N37_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200204_8N51_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200204_8N52_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200204_8N54_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200204_9N42_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200204_9N43_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200204_9N47_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200204_9N56_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200205_1N20_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200205_1S13_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200205_2S10_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200205_2S4_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200205_2S9_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200205_6S15_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200205_6S22_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200205_8C11_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200205_8C18_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200205_8C29_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200205_8C35_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200205_8C36_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200205_8N9_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200205_8S18_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200205_9C16_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200206_2N13_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200206_2S20_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200206_5N15_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200206_6S32_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200206_6S53_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200206_7S23_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200206_7S50_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200206_8N33_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200206_9N30_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200208_1C1_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200208_1N1_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200208_1S17_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200208_1S2_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200208_2N8_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200208_2S16_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200208_2S7_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200208_3N26_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200208_6N16_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200208_9N28_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200209_5C27_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200209_8C31_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200209_8C32_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200209_9C23_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200210_2N49_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200210_2S45_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200210_5N10_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200210_5N11_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200210_6N17_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200210_8N35_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200210_8S41_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200210_9N39_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200210_FL3A_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200211_1N23_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200211_1N3_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200211_1N5_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200211_1N7_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200211_1S12_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200211_2N14_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200211_2N21_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200211_2S6_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200211_FL2A_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200212_1C5_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200212_2C12_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200212_2C13_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200212_5N24_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200212_5N32_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200212_6S26_stratigraphy_v01.csv',
#  'snowex-data/tutorial-data/core-datasets/pits/SnowEx20_SnowPits_GMIOP_20200212_FL1B_stratigraphy_v01.csv']

# %%
# ehhhhhhhhhhhh
all_strat_list = []
for file in csv_files:
    with fs.open(file, 'rb') as f:
        df = pd.read_csv(f, sep=',', header=0, parse_dates=[[2,3]]) #parse the date[2] and time[3] columns such that they are read in as datetime dtypes
        all_strat_list.append(df)
all_strat = pd.concat(all_strat_list)
all_strat
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-36-f4afea3e1dc4> in <module>
#       2 for file in csv_files:
#       3     with fs.open(file, 'rb') as f:
# ----> 4         df = pd.read_csv(f, sep=',', header=0, parse_dates=[[2,3]]) #parse the date[2] and time[3] columns such that they are read in as datetime dtypes
#       5         all_strat_list.append(df)
#       6 all_strat = pd.concat(all_strat_list)
#
# /srv/conda/envs/notebook/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# /srv/conda/envs/notebook/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     466
#     467     with parser:
# --> 468         return parser.read(nrows)
#     469
#     470
#
# /srv/conda/envs/notebook/lib/python3.8/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1055     def read(self, nrows=None):
#    1056         nrows = validate_integer("nrows", nrows)
# -> 1057         index, columns, col_dict = self._engine.read(nrows)
#    1058
#    1059         if index is None:
#
# /srv/conda/envs/notebook/lib/python3.8/site-packages/pandas/io/parsers.py in read(self, nrows)
#    2034     def read(self, nrows=None):
#    2035         try:
# -> 2036             data = self._reader.read(nrows)
#    2037         except StopIteration:
#    2038             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 2 fields in line 8, saw 7

# %%
help(s3fs)
